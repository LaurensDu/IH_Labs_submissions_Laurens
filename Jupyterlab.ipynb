# %% [markdown]
# # Holiday preference of Laurens

# %% [markdown]
# This notebook introduces my holiday preference.

# %%
person_name = input('Your name: ')

# %% [markdown]
# ![Passbild%20L.A.%20Duin.jpg](attachment:Passbild%20L.A.%20Duin.jpg)

# %% [markdown]
# ![](https://toposmagazine.com/wp-content/uploads/2022/05/dimitry-anikin-ECkAbFv_Nnc-unsplash-aspect-ratio-16-9.jpg)

# %% [markdown]
# ![](https://duckduckgo.com/?t=ffab&q=barcelona&iax=images&ia=images&iai=https%3A%2F%2Fwww.llorenteycuenca.com%2Fwp-content%2Fuploads%2F2019%2F02%2FiStock-619257048-1024x622.jpg)

# %% [markdown]
# The _top three things_ I like to do when I visit _**Barcelona**_ are:
#
# - Visit my brother
# - Go to the beach
# - Go on hikes in the surrounding area

# %% [markdown]
# I used the input function to request the name of the user.
